# %%
# Библиотеки использованные для обработки данных
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pylab

# %%
# Датафрейм читается из csv файла - stroke_data.csv - взятого с kaggle
df = pd.read_csv('data/stroke_data.csv')

# %%
# Удаление столбца id, который тут не нужен
df.drop('id', axis=1, inplace=True)

# %%
# Первые 5 строк датафрейма
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %% [markdown]
# # EDA/Разведовочный анализ

# %% [markdown]
# ## Анализ атрибута gender(пол)

# %%
# Просмотр значений столбца gender
df['gender'].value_counts()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %% [markdown]
# - Мы имеем значение 'other' в gender и поскольку есть только 1 случай мы его заменим на 'female'

# %%
# Замена 'other' в gender на 'Female' 
df['gender'] = df['gender'].replace('Other', 'Female')
# # Круговая диаграмма распределения количества значений атрибута gender
df['gender'].value_counts().plot(kind='pie', title='Распределение значений атрибута gender',autopct='%1.0f%%')
pylab.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# - Заметное преобладание женщин, нежели мужчин

# %% [markdown]
# ## Анализирование атрибута stroke(инсульт)

# %%
# Подсчет количества значений в атрибуте stroke
df['stroke'].value_counts()
# Out:
# 0    4861
# 1     249
# Name: stroke, dtype: int64

# %%
# Круговая диаграмма распределения количества значений атрибута stroke
df['stroke'].value_counts().plot(kind='pie', title='Распределение значений атрибута stroke',autopct='%1.0f%%')
pylab.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# - Порядка 5% людей с которыми случился инсульт

# %% [markdown]
# ## Анализирование атрибута hypertension(гипертония)

# %%
# Подсчет количества значений в атрибуте hypertension
df['hypertension'].value_counts()
# Out:
# 0    4612
# 1     498
# Name: hypertension, dtype: int64

# %%
# Круговая диаграмма распределения количества значений атрибута hypertension
df['hypertension'].value_counts().plot(kind='pie', title='Распределение значений атрибута hypertension',autopct='%1.0f%%')
pylab.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# - Порядка 10% людей с гипертонией

# %% [markdown]
# ## Анализирование атрибута Work type(тип работы)

# %%
# Подсчет количества значений в атрибуте work_type
df['work_type'].value_counts()
# Out:
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64

# %%
# Круговая диаграмма распределения количества значений атрибута work_type
df['work_type'].value_counts().plot(kind='pie', title='Распределение значений атрибута work_type',autopct='%1.0f%%')
pylab.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## Анализирование атрибута Smoking status(статус курения)

# %%
# Подсчет количества значений в атрибуте smoking_status
df['smoking_status'].value_counts()
# Out:
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64

# %%
# Круговая диаграмма распределения количества значений атрибута smoking_status
df['smoking_status'].value_counts().plot(kind='pie', title='Распределение значений атрибута smoking_status',autopct='%1.0f%%')
pylab.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## Анализирование атрибута Residense type(вид проживания)

# %%
# Подсчет количества значений в атрибуте Residence_type
df['Residence_type'].value_counts()
# Out:
# Urban    2596
# Rural    2514
# Name: Residence_type, dtype: int64

# %%
# Круговая диаграмма распределения количества значений атрибута Residence_type
df['Residence_type'].value_counts().plot(kind='pie', title='Распределение значений атрибута Residence_type',autopct='%1.0f%%')
pylab.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# - Мы имеем почти равный процент людей с городских и сельских районов

# %% [markdown]
# ## Анализирование атрибута bmi(индекс массы тела)

# %%
# Графическое представление атрибута bmi
sns.histplot(data=df['bmi']).set_title('Распределение значений атрибута bmi')
# Out:
# Text(0.5, 1.0, 'Распределение значений атрибута bmi')

# %%
# Коробчатая диаграмма для атрибута bmi
sns.boxplot(data=df['bmi']).set_title('Диаграмма для обнаружения выбросов атрибута bmi')
# Out:
# Text(0.5, 1.0, 'Диаграмма для обнаружения выбросов атрибута bmi')

# %% [markdown]
# - Основываясь на гистограмме и коробчатой диаграмме видно большое количество выбросов

# %% [markdown]
# ## Анализирование атрибута age(возраст)

# %%
# Графическое представление данных атрибута age
sns.histplot(data=df['age']).set_title('Распределение значений атрибута age')
# Out:
# Text(0.5, 1.0, 'Распределение значений атрибута age')

# %%
# Коробчатая диаграмма для атрибута age
sns.boxplot(data=df['age']).set_title('Диаграмма для обнаружения выбросов атрибута age')
# Out:
# Text(0.5, 1.0, 'Диаграмма для обнаружения выбросов атрибута age')

# %% [markdown]
# - Атрибут age не имеет выбросов и имеет нормальное распределение

# %% [markdown]
# ## Анализирование атрибута Average glucose level(средний уровень глюкозы)

# %%
# Графическое представление данных атрибута avg_glucose_level
sns.histplot(data=df['avg_glucose_level']).set_title('Распределение значений атрибута avg_glucose_level')
# Out:
# Text(0.5, 1.0, 'Распределение значений атрибута avg_glucose_level')

# %%
# Коробчатая диаграмма для атрибута avg_glucose_level
sns.boxplot(data=df['avg_glucose_level']).set_title('Диаграмма для обнаружения выбросов атрибута avg_glucose_level')
# Out:
# Text(0.5, 1.0, 'Диаграмма для обнаружения выбросов атрибута avg_glucose_level')

# %% [markdown]
# - Присутствует большое количество выбросов как на гистограмме, так и на коробчатой диаграмме

# %% [markdown]
# ## Анализирование атрибута Heart disease(сердечная болезнь)

# %%
# Подсчет количества значений атрибута heart_disease
df['heart_disease'].value_counts()
# Out:
# 0    4834
# 1     276
# Name: heart_disease, dtype: int64

# %% [markdown]
# - Порядка 6% людей имеют сердечные заболевания

# %%
# Круговая диаграмма распределения количества значений атрибута heart_disease
df['heart_disease'].value_counts().plot(kind='pie', title='Распределение значений атрибута heart_disease',autopct='%1.0f%%')
pylab.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## Анализирование атрибута Ever married(Когда-либо замужем/женат)

# %%
# Подсчет количества значений атрибута ever_married
df['ever_married'].value_counts()
# Out:
# Yes    3353
# No     1757
# Name: ever_married, dtype: int64

# %% [markdown]
# - Результат сообщает нам о том, что более 60% людей женаты, остальные нет

# %%
# Круговая диаграмма распределения количества значений атрибута ever_married
df['ever_married'].value_counts().plot(kind='pie', title='Распределение значений атрибута ever_married',autopct='%1.0f%%')
pylab.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# # Перекрестный анализ всех атрибутов с целевым атрибутом

# %%
# Сопоставление stroke с gender
sns.countplot(data=df, x='stroke', hue='gender', palette='husl').set_title('Сопоставление атрибутов stroke к gender')
# Out:
# Text(0.5, 1.0, 'Сопоставление атрибутов stroke к gender')

# %% [markdown]
# - Женщины больше подвержены инсульту, чем мужчины

# %%
# Сопоставление stroke с work_type
sns.countplot(data=df, x='stroke', hue='work_type', palette='husl').set_title('Сопоставление атрибутов stroke к work_type')
# Out:
# Text(0.5, 1.0, 'Сопоставление атрибутов stroke к work_type')

# %% [markdown]
# - На графике выше можно увидеть, что люди никогда неработавшие не получали инсульта, а чаще всего кто получал - люди с частным типом работы

# %%
# Сопоставление stroke с smoking_status
sns.countplot(data=df, x='stroke', hue='smoking_status', palette='husl').set_title('Сопоставление атрибутов stroke к smoking_status')
# Out:
# Text(0.5, 1.0, 'Сопоставление атрибутов stroke к smoking_status')

# %% [markdown]
# - Люди, которые никогда не курили получили инсульт больше, чем те, которые бросили курить или курят до сих пор

# %%
# Сопоставление stroke с Residence_type
sns.countplot(data=df, x='stroke', hue='Residence_type', palette='husl').set_title('Сопоставление атрибутов stroke к Residence_type')
# Out:
# Text(0.5, 1.0, 'Сопоставление атрибутов stroke к Residence_type')

# %% [markdown]
# - Основываясь на анализе типа проживания, люди которые живут в городе чаще получали инсульт

# %%
# Сопоставление stroke с heart_disease
sns.countplot(data=df, x='stroke', hue='heart_disease', palette='husl').set_title('Сопоставление атрибутов stroke к heart_disease')
# Out:
# Text(0.5, 1.0, 'Сопоставление атрибутов stroke к heart_disease')

# %% [markdown]
# - Большинство людей без сердечных заболеваний чаще страдают от инсульта по сравнению с теми, у кого были сердечные заболевания

# %%
# Сопоставление stroke с ever_married
sns.countplot(data=df, x='stroke', hue='ever_married', palette='husl').set_title('Сопоставление атрибутов stroke к ever_married')
# Out:
# Text(0.5, 1.0, 'Сопоставление атрибутов stroke к ever_married')

# %% [markdown]
# - Большое количество людей в браке получают инсульт по сравнению с теми, кто не в браке

# %% [markdown]
# ## Нахождение корреляции между атрибутами с помощью корреляционной матрицы

# %%
# Построение корреляционной матрицы между атрибутами в датасете, чтобы узнать коррелляцию между ними
corrmat = df.corr()
f, ax = plt.subplots(figsize=(10,10))
sns.heatmap(corrmat, ax=ax, cmap="rocket_r", linewidths=0.8, annot=True).set_title('Корреляционная матрица для визуализации корреляции между атрибутами')
# Out:
# /var/folders/np/7w4_pgnx3q99j4gqz4v_sxww0000gn/T/ipykernel_32393/3835884754.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()
# Text(0.5, 1.0, 'Корреляционная матрица для визуализации корреляции между атрибутами')

# %% [markdown]
# - Мы имеем слабую корреляцию между атрибутами, смотря на тепловую карту
# - Самую высокую корреляцию имеет age и bmi - 0.33
# - Остальные ниже этого показателя
# - Из полученной тепловой карты невозможно получить какую-либо дельную информацию
